# %% [markdown]
# # Preparación de datos

# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-OA06NEQ:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
##
## Row representa una fila en un RDD
##
from pyspark.sql import Row
##
## Crea un DataFrame a partir del archivo con
## formato CSV
##
nombre_archivo="evaluacion"
df = spark.read.load("D:\\CLASES\\ELECTIVA 3 BigData\\Taller_final\\"+nombre_archivo+".csv",
                     format="csv",
                     sep="|",
                     inferSchema= True,
                     encoding='UTF-8',
                     decimal=".",
                     header="true")
df.printSchema()
# Out:
# root
#  |-- cod_alumno: integer (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- sexo_f: integer (nullable = true)
#  |-- puntaje_ingreso: double (nullable = true)
#  |-- promedio_notas: double (nullable = true)
#  |-- total_creditos_logrados: double (nullable = true)
#  |-- biologia: double (nullable = true)
#  |-- matematicas: double (nullable = true)
#  |-- filosofia: double (nullable = true)
#  |-- fisica: double (nullable = true)
#  |-- historia: double (nullable = true)
#  |-- quimica: double (nullable = true)
#  |-- lenguaje: double (nullable = true)
#  |-- geografia: double (nullable = true)
#  |-- idiomas: double (nullable = true)
#  |-- sociales: double (nullable = true)
#  |-- lecturacritica: double (nullable = true)
#  |-- ciencias: double (nullable = true)
#  |-- razonamiento: double (nullable = true)
#  |-- competenciaciud: double (nullable = true)
#  |-- valor_matricula: double (nullable = true)
#  |-- valor_servicios: double (nullable = true)
#  |-- ingresos: double (nullable = true)
#  |-- vive_familia: integer (nullable = true)
#  |-- estrato: integer (nullable = true)
#  |-- estrato_vivira: integer (nullable = true)
#  |-- actualmente_trabaja: integer (nullable = true)
#  |-- valor_matric_colegio: integer (nullable = true)
#  |-- ano_pago_colegio: integer (nullable = true)
#  |-- ingresos_familiares: integer (nullable = true)
#  |-- ano_ingresos: double (nullable = true)
#  |-- numero_aportantes: double (nullable = true)
#  |-- numero_hermanos: double (nullable = true)
#  |-- numero_hermanos_est_superior: double (nullable = true)
#  |-- edad_inicio: double (nullable = true)
#  |-- edad_reporte: double (nullable = true)
#  |-- anio_reporte: double (nullable = true)
#  |-- clase: string (nullable = true)

# %% [markdown]
# # Contar cantidad de registros

# %%
df.count()
# Out:
# 264

# %% [markdown]
# # Contar cantidad de registros por clase

# %%
df.groupby("clase").count().show()
# Out:
# +-----+-----+
# |clase|count|
# +-----+-----+
# | null|  264|
# +-----+-----+

# %% [markdown]
# # Contar estudiantes por ciudad

# %%
df.groupby("ciudad").count().show()
# Out:
# +--------------------+-----+
# |              ciudad|count|
# +--------------------+-----+
# |TUMACO           ...|   32|
# |PASTO            ...|  193|
# |IPIALES          ...|   30|
# |TUQUERRES        ...|    9|
# +--------------------+-----+

# %% [markdown]
# # Contar estudiantes por año

# %%
df.groupby("anio_reporte").count().orderBy("anio_reporte").show()
# Out:
# +------------+-----+
# |anio_reporte|count|
# +------------+-----+
# |      2018.0|  264|
# +------------+-----+

# %% [markdown]
# # Explorar valores faltantes

# %%
from pyspark.sql.functions import isnan, when, count, col
Dict_Null = {col:df.filter(df[col].isNull()).count() for col in df.columns}
Dict_Null
# Out:
# {'cod_alumno': 0,
#  'ciudad': 0,
#  'sexo_f': 0,
#  'puntaje_ingreso': 0,
#  'promedio_notas': 1,
#  'total_creditos_logrados': 1,
#  'biologia': 3,
#  'matematicas': 3,
#  'filosofia': 3,
#  'fisica': 3,
#  'historia': 3,
#  'quimica': 4,
#  'lenguaje': 4,
#  'geografia': 4,
#  'idiomas': 5,
#  'sociales': 13,
#  'lecturacritica': 129,
#  'ciencias': 129,
#  'razonamiento': 129,
#  'competenciaciud': 129,
#  'valor_matricula': 11,
#  'valor_servicios': 11,
#  'ingresos': 11,
#  'vive_familia': 0,
#  'estrato': 12,
#  'estrato_vivira': 12,
#  'actualmente_trabaja': 4,
#  'valor_matric_colegio': 4,
#  'ano_pago_colegio': 11,
#  'ingresos_familiares': 4,
#  'ano_ingresos': 11,
#  'numero_aportantes': 11,
#  'numero_hermanos': 4,
#  'numero_hermanos_est_superior': 4,
#  'edad_inicio': 0,
#  'edad_reporte': 0,
#  'anio_reporte': 0,
#  'clase': 264}

# %%
for col_name in df.dtypes:
    df.describe(col_name[0]).show()
# Out:
# +-------+-------------------+
# |summary|         cod_alumno|
# +-------+-------------------+
# |  count|                264|
# |   mean|9.203732674545455E8|
# | stddev|9.448490349661958E8|
# |    min|               7644|
# |    max|         2141601270|
# +-------+-------------------+
#
# +-------+--------------------+
# |summary|              ciudad|
# +-------+--------------------+
# |  count|                 264|
# |   mean|                null|
# | stddev|                null|
# |    min|IPIALES          ...|
# |    max|TUQUERRES        ...|
# +-------+--------------------+
#
# +-------+-------------------+
# |summary|             sexo_f|
# +-------+-------------------+
# |  count|                264|
# |   mean|0.20833333333333334|
# | stddev|0.40688778297473344|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|   puntaje_ingreso|
# +-------+------------------+
# |  count|               264|
# |   mean| 60.23227272727273|
# | stddev|14.921546882109602|
# |    min|               0.0|
# |    max|              91.7|
# +-------+------------------+
#
# +-------+------------------+
# |summary|    promedio_notas|
# +-------+------------------+
# |  count|               263|
# |   mean|2.9403407033880433|
# | stddev|0.9194403229966699|
# |    min|              0.06|
# |    max|4.5600000000000005|
# +-------+------------------+
#
# +-------+-----------------------+
# |summary|total_creditos_logrados|
# +-------+-----------------------+
# |  count|                    263|
# |   mean|        88.212927756654|
# | stddev|      77.52606249891946|
# |    min|                    0.0|
# |    max|                  217.0|
# +-------+-----------------------+
#
# +-------+------------------+
# |summary|          biologia|
# +-------+------------------+
# |  count|               261|
# |   mean|29.174291187739463|
# | stddev|28.420423980074453|
# |    min|               0.0|
# |    max|             88.69|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|      matematicas|
# +-------+-----------------+
# |  count|              261|
# |   mean| 65.1394252873563|
# | stddev|16.73350682977962|
# |    min|              0.0|
# |    max|           113.46|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|         filosofia|
# +-------+------------------+
# |  count|               261|
# |   mean|25.078544061302683|
# | stddev|24.736888014488013|
# |    min|               0.0|
# |    max|             84.61|
# +-------+------------------+
#
# +-------+------------------+
# |summary|            fisica|
# +-------+------------------+
# |  count|               261|
# |   mean|30.535708812260534|
# | stddev|29.832973935271287|
# |    min|               0.0|
# |    max|              94.0|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|         historia|
# +-------+-----------------+
# |  count|              261|
# |   mean|3.499693486590038|
# | stddev|12.64644501210319|
# |    min|              0.0|
# |    max|             62.0|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|           quimica|
# +-------+------------------+
# |  count|               260|
# |   mean| 29.93692307692307|
# | stddev|29.438710282260377|
# |    min|               0.0|
# |    max|            103.04|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|         lenguaje|
# +-------+-----------------+
# |  count|              260|
# |   mean|28.79819230769231|
# | stddev|27.79951405441679|
# |    min|              0.0|
# |    max|             77.1|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|         geografia|
# +-------+------------------+
# |  count|               260|
# |   mean|3.2798846153846153|
# | stddev|12.137387036726606|
# |    min|               0.0|
# |    max|              56.0|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|          idiomas|
# +-------+-----------------+
# |  count|              259|
# |   mean|54.10961389961392|
# | stddev|16.29012693349145|
# |    min|              0.0|
# |    max|             95.0|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|          sociales|
# +-------+------------------+
# |  count|               251|
# |   mean|56.244701195219136|
# | stddev| 17.67389451734843|
# |    min|               0.0|
# |    max|             100.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|    lecturacritica|
# +-------+------------------+
# |  count|               135|
# |   mean| 56.45925925925926|
# | stddev|24.105725759092625|
# |    min|               0.0|
# |    max|             100.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|          ciencias|
# +-------+------------------+
# |  count|               135|
# |   mean| 60.17777777777778|
# | stddev|25.512322649362492|
# |    min|               0.0|
# |    max|             100.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|      razonamiento|
# +-------+------------------+
# |  count|               135|
# |   mean|13.303703703703704|
# | stddev|29.294509208421626|
# |    min|               0.0|
# |    max|              96.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|   competenciaciud|
# +-------+------------------+
# |  count|               135|
# |   mean|10.844444444444445|
# | stddev|23.800121242218044|
# |    min|               0.0|
# |    max|              79.0|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|  valor_matricula|
# +-------+-----------------+
# |  count|              253|
# |   mean|7994.083003952569|
# | stddev|50994.52169243193|
# |    min|              0.0|
# |    max|         584000.0|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|   valor_servicios|
# +-------+------------------+
# |  count|               253|
# |   mean|1598.8142292490118|
# | stddev|10198.904711709332|
# |    min|               0.0|
# |    max|          116800.0|
# +-------+------------------+
#
# +-------+--------+
# |summary|ingresos|
# +-------+--------+
# |  count|     253|
# |   mean|     0.0|
# | stddev|     0.0|
# |    min|     0.0|
# |    max|     0.0|
# +-------+--------+
#
# +-------+-------------------+
# |summary|       vive_familia|
# +-------+-------------------+
# |  count|                264|
# |   mean| 0.7424242424242424|
# | stddev|0.43812965980598173|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|           estrato|
# +-------+------------------+
# |  count|               252|
# |   mean|2.3531746031746033|
# | stddev| 2.401499747474763|
# |    min|                 0|
# |    max|                10|
# +-------+------------------+
#
# +-------+------------------+
# |summary|    estrato_vivira|
# +-------+------------------+
# |  count|               252|
# |   mean|1.4365079365079365|
# | stddev|1.0636779890919026|
# |    min|                 0|
# |    max|                 5|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|actualmente_trabaja|
# +-------+-------------------+
# |  count|                260|
# |   mean|0.09615384615384616|
# | stddev|  0.295370677698104|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
# +-------+--------------------+
# |summary|valor_matric_colegio|
# +-------+--------------------+
# |  count|                 260|
# |   mean|  110733.92307692308|
# | stddev|   697834.3087662763|
# |    min|                   0|
# |    max|             6517050|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|  ano_pago_colegio|
# +-------+------------------+
# |  count|               253|
# |   mean|1836.7351778656127|
# | stddev| 567.9703465072587|
# |    min|                 0|
# |    max|              2018|
# +-------+------------------+
#
# +-------+--------------------+
# |summary| ingresos_familiares|
# +-------+--------------------+
# |  count|                 260|
# |   mean|3.9134722765384614E7|
# | stddev| 2.631290012216359E8|
# |    min|                   0|
# |    max|          2147483647|
# +-------+--------------------+
#
# +-------+-----------------+
# |summary|     ano_ingresos|
# +-------+-----------------+
# |  count|              253|
# |   mean|1798.889328063241|
# | stddev|623.0124552921473|
# |    min|              0.0|
# |    max|           2018.0|
# +-------+-----------------+
#
# +-------+------------------+
# |summary| numero_aportantes|
# +-------+------------------+
# |  count|               253|
# |   mean|1.4861660079051384|
# | stddev|1.0335667574826917|
# |    min|               0.0|
# |    max|               8.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|   numero_hermanos|
# +-------+------------------+
# |  count|               260|
# |   mean|2.0307692307692307|
# | stddev|2.2726796441805788|
# |    min|               0.0|
# |    max|              17.0|
# +-------+------------------+
#
# +-------+----------------------------+
# |summary|numero_hermanos_est_superior|
# +-------+----------------------------+
# |  count|                         260|
# |   mean|         0.38846153846153847|
# | stddev|          1.4857955302087693|
# |    min|                         0.0|
# |    max|                        13.0|
# +-------+----------------------------+
# +-------+------------------+
# |summary|       edad_inicio|
# +-------+------------------+
# |  count|               264|
# |   mean|19.522727272727273|
# | stddev| 3.876351051784115|
# |    min|               0.0|
# |    max|              40.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|      edad_reporte|
# +-------+------------------+
# |  count|               264|
# |   mean|23.617424242424242|
# | stddev| 5.632051084986429|
# |    min|               1.0|
# |    max|              48.0|
# +-------+------------------+
#
# +-------+------------+
# |summary|anio_reporte|
# +-------+------------+
# |  count|         264|
# |   mean|      2018.0|
# | stddev|         0.0|
# |    min|      2018.0|
# |    max|      2018.0|
# +-------+------------+
#
# +-------+-----+
# |summary|clase|
# +-------+-----+
# |  count|    0|
# |   mean| null|
# | stddev| null|
# |    min| null|
# |    max| null|
# +-------+-----+

# %% [markdown]
# # Métodos para autocompletar los valores faltantes

# %% [markdown]
# 1 imputar valores faltantes con un cero

# %%
complete_dict = dict()
for col_name in df.dtypes:
    if col_name[1]=='string':
        complete_dict[col_name[0]]="DESCONOCIDO"
    else:
        complete_dict[col_name[0]]=0    
df_ml_complete = df.na.fill(complete_dict)

# %% [markdown]
# 2 imputar valores faltantes con un valor fuera de rango -99

# %%
complete_dict = dict()
for col_name in df.dtypes:
    if col_name[1]=='string':
        complete_dict[col_name[0]]="DESCONOCIDO"
    else:
        complete_dict[col_name[0]]=-99    
df_ml_complete = df.na.fill(complete_dict)

# %% [markdown]
# 3 imputar valores faltantes con el promedio

# %%
complete_dict = dict()
for col_name in df.dtypes:
    if col_name[1]=='string':
        complete_dict[col_name[0]]="DESCONOCIDO"
    else:
        d=df.selectExpr("avg("+col_name[0]+")").rdd.map(list)
        v=max(d.collect()[0])
        complete_dict[col_name[0]]=v   
df_ml_complete = df.na.fill(complete_dict)

# %%
from pyspark.sql.functions import isnan, when, count, col
Dict_Null = {col:df_ml_complete.filter(df_ml_complete[col].isNull()).count() for col in df_ml_complete.columns}
Dict_Null
# Out:
# {'cod_alumno': 0,
#  'ciudad': 0,
#  'sexo_f': 0,
#  'puntaje_ingreso': 0,
#  'promedio_notas': 0,
#  'total_creditos_logrados': 0,
#  'biologia': 0,
#  'matematicas': 0,
#  'filosofia': 0,
#  'fisica': 0,
#  'historia': 0,
#  'quimica': 0,
#  'lenguaje': 0,
#  'geografia': 0,
#  'idiomas': 0,
#  'sociales': 0,
#  'lecturacritica': 0,
#  'ciencias': 0,
#  'razonamiento': 0,
#  'competenciaciud': 0,
#  'valor_matricula': 0,
#  'valor_servicios': 0,
#  'ingresos': 0,
#  'vive_familia': 0,
#  'estrato': 0,
#  'estrato_vivira': 0,
#  'actualmente_trabaja': 0,
#  'valor_matric_colegio': 0,
#  'ano_pago_colegio': 0,
#  'ingresos_familiares': 0,
#  'ano_ingresos': 0,
#  'numero_aportantes': 0,
#  'numero_hermanos': 0,
#  'numero_hermanos_est_superior': 0,
#  'edad_inicio': 0,
#  'edad_reporte': 0,
#  'anio_reporte': 0,
#  'clase': 0}

# %%
for col_name in df_ml_complete.dtypes:
    df_ml_complete.describe(col_name[0]).show()
# Out:
# +-------+-------------------+
# |summary|         cod_alumno|
# +-------+-------------------+
# |  count|                264|
# |   mean|9.203732674545455E8|
# | stddev|9.448490349661958E8|
# |    min|               7644|
# |    max|         2141601270|
# +-------+-------------------+
#
# +-------+--------------------+
# |summary|              ciudad|
# +-------+--------------------+
# |  count|                 264|
# |   mean|                null|
# | stddev|                null|
# |    min|IPIALES          ...|
# |    max|TUQUERRES        ...|
# +-------+--------------------+
#
# +-------+-------------------+
# |summary|             sexo_f|
# +-------+-------------------+
# |  count|                264|
# |   mean|0.20833333333333334|
# | stddev|0.40688778297473344|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|   puntaje_ingreso|
# +-------+------------------+
# |  count|               264|
# |   mean| 60.23227272727273|
# | stddev|14.921546882109602|
# |    min|               0.0|
# |    max|              91.7|
# +-------+------------------+
#
# +-------+------------------+
# |summary|    promedio_notas|
# +-------+------------------+
# |  count|               264|
# |   mean| 2.554203049208544|
# | stddev| 6.340753913888072|
# |    min|             -99.0|
# |    max|4.5600000000000005|
# +-------+------------------+
#
# +-------+-----------------------+
# |summary|total_creditos_logrados|
# +-------+-----------------------+
# |  count|                    264|
# |   mean|      87.50378787878788|
# | stddev|      78.23169245407259|
# |    min|                  -99.0|
# |    max|                  217.0|
# +-------+-----------------------+
#
# +-------+------------------+
# |summary|          biologia|
# +-------+------------------+
# |  count|               264|
# |   mean|27.717765151515152|
# | stddev|31.365210982958057|
# |    min|             -99.0|
# |    max|             88.69|
# +-------+------------------+
#
# +-------+------------------+
# |summary|       matematicas|
# +-------+------------------+
# |  count|               264|
# |   mean| 63.27420454545453|
# | stddev|24.096561863913795|
# |    min|             -99.0|
# |    max|            113.46|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         filosofia|
# +-------+------------------+
# |  count|               264|
# |   mean|23.668560606060606|
# | stddev|27.902543096073746|
# |    min|             -99.0|
# |    max|             84.61|
# +-------+------------------+
#
# +-------+------------------+
# |summary|            fisica|
# +-------+------------------+
# |  count|               264|
# |   mean| 29.06371212121212|
# | stddev|32.696793366229684|
# |    min|             -99.0|
# |    max|              94.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|          historia|
# +-------+------------------+
# |  count|               264|
# |   mean|2.3349242424242425|
# | stddev|16.630960248209036|
# |    min|             -99.0|
# |    max|              62.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|           quimica|
# +-------+------------------+
# |  count|               264|
# |   mean|27.983333333333327|
# | stddev| 33.20351554218241|
# |    min|             -99.0|
# |    max|            103.04|
# +-------+------------------+
#
# +-------+------------------+
# |summary|          lenguaje|
# +-------+------------------+
# |  count|               264|
# |   mean|26.861856060606062|
# | stddev|31.712721475553735|
# |    min|             -99.0|
# |    max|              77.1|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         geografia|
# +-------+------------------+
# |  count|               264|
# |   mean| 1.730189393939394|
# | stddev|17.371535553672572|
# |    min|             -99.0|
# |    max|              56.0|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|          idiomas|
# +-------+-----------------+
# |  count|              264|
# |   mean|51.20981060606062|
# | stddev|26.41132918066543|
# |    min|            -99.0|
# |    max|             95.0|
# +-------+-----------------+
#
# +-------+-----------------+
# |summary|         sociales|
# +-------+-----------------+
# |  count|              264|
# |   mean|48.60007575757577|
# | stddev|37.80957502395838|
# |    min|            -99.0|
# |    max|            100.0|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|    lecturacritica|
# +-------+------------------+
# |  count|               264|
# |   mean|-19.50378787878788|
# | stddev|  79.7358280007566|
# |    min|             -99.0|
# |    max|             100.0|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|           ciencias|
# +-------+-------------------+
# |  count|                264|
# |   mean|-17.602272727272727|
# | stddev|  81.77296862568275|
# |    min|              -99.0|
# |    max|              100.0|
# +-------+-------------------+
#
# +-------+-------------------+
# |summary|       razonamiento|
# +-------+-------------------+
# |  count|                264|
# |   mean|-41.571969696969695|
# | stddev|  60.00521626805042|
# |    min|              -99.0|
# |    max|               96.0|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|   competenciaciud|
# +-------+------------------+
# |  count|               264|
# |   mean|-42.82954545454545|
# | stddev|57.575717366011645|
# |    min|             -99.0|
# |    max|              79.0|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|  valor_matricula|
# +-------+-----------------+
# |  count|              264|
# |   mean|7656.871212121212|
# | stddev|49942.99606633757|
# |    min|            -99.0|
# |    max|         584000.0|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|   valor_servicios|
# +-------+------------------+
# |  count|               264|
# |   mean|1528.0719696969697|
# | stddev| 9989.126554118347|
# |    min|             -99.0|
# |    max|          116800.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|          ingresos|
# +-------+------------------+
# |  count|               264|
# |   mean|            -4.125|
# | stddev|19.820379246121302|
# |    min|             -99.0|
# |    max|               0.0|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|       vive_familia|
# +-------+-------------------+
# |  count|                264|
# |   mean| 0.7424242424242424|
# | stddev|0.43812965980598173|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|           estrato|
# +-------+------------------+
# |  count|               264|
# |   mean|-2.253787878787879|
# | stddev|21.281563113718853|
# |    min|               -99|
# |    max|                10|
# +-------+------------------+
#
# +-------+------------------+
# |summary|    estrato_vivira|
# +-------+------------------+
# |  count|               264|
# |   mean|-3.128787878787879|
# | stddev|20.986291126714445|
# |    min|               -99|
# |    max|                 5|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|actualmente_trabaja|
# +-------+-------------------+
# |  count|                264|
# |   mean|-1.4053030303030303|
# | stddev| 12.131665597682085|
# |    min|                -99|
# |    max|                  1|
# +-------+-------------------+
#
# +-------+--------------------+
# |summary|valor_matric_colegio|
# +-------+--------------------+
# |  count|                 264|
# |   mean|  109054.63636363637|
# | stddev|   692640.0872475386|
# |    min|                 -99|
# |    max|             6517050|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|  ano_pago_colegio|
# +-------+------------------+
# |  count|               264|
# |   mean|1756.0795454545455|
# | stddev| 677.7089826255454|
# |    min|               -99|
# |    max|              2018|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|ingresos_familiares|
# +-------+-------------------+
# |  count|                264|
# |   mean|3.854177092045455E7|
# | stddev|2.611642766329906E8|
# |    min|                -99|
# |    max|         2147483647|
# +-------+-------------------+
#
# +-------+-----------------+
# |summary|     ano_ingresos|
# +-------+-----------------+
# |  count|              264|
# |   mean|1719.810606060606|
# | stddev|718.5307477599252|
# |    min|            -99.0|
# |    max|           2018.0|
# +-------+-----------------+
# +-------+-------------------+
# |summary|  numero_aportantes|
# +-------+-------------------+
# |  count|                264|
# |   mean|-2.7007575757575757|
# | stddev| 20.143341826921777|
# |    min|              -99.0|
# |    max|                8.0|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|   numero_hermanos|
# +-------+------------------+
# |  count|               264|
# |   mean|               0.5|
# | stddev|12.568897577424488|
# |    min|             -99.0|
# |    max|              17.0|
# +-------+------------------+
#
# +-------+----------------------------+
# |summary|numero_hermanos_est_superior|
# +-------+----------------------------+
# |  count|                         264|
# |   mean|         -1.1174242424242424|
# | stddev|          12.252936304947411|
# |    min|                       -99.0|
# |    max|                        13.0|
# +-------+----------------------------+
#
# +-------+------------------+
# |summary|       edad_inicio|
# +-------+------------------+
# |  count|               264|
# |   mean|19.522727272727273|
# | stddev| 3.876351051784115|
# |    min|               0.0|
# |    max|              40.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|      edad_reporte|
# +-------+------------------+
# |  count|               264|
# |   mean|23.617424242424242|
# | stddev| 5.632051084986429|
# |    min|               1.0|
# |    max|              48.0|
# +-------+------------------+
#
# +-------+------------+
# |summary|anio_reporte|
# +-------+------------+
# |  count|         264|
# |   mean|      2018.0|
# | stddev|         0.0|
# |    min|      2018.0|
# |    max|      2018.0|
# +-------+------------+
#
# +-------+-----------+
# |summary|      clase|
# +-------+-----------+
# |  count|        264|
# |   mean|       null|
# | stddev|       null|
# |    min|DESCONOCIDO|
# |    max|DESCONOCIDO|
# +-------+-----------+

# %% [markdown]
# # Transformar la ciudad a Dummies

# %%
df_ml_complete.createOrReplaceTempView("estudiantes")
sql=("select case when trim(e.ciudad)='LA UNION' then 1 else 0 end ciudad_union,"+
     "case when trim(e.ciudad)='TUMACO' then 1 else 0 end ciudad_tumaco,"+
     "case when trim(e.ciudad)='PASTO' then 1 else 0 end ciudad_pasto,"+
     "case when trim(e.ciudad)='IPIALES' then 1 else 0 end ciudad_ipiales,"+
     "case when trim(e.ciudad)='SAMANIEGO' then 1 else 0 end ciudad_samaniego,"+
     "e.*"+
     "from estudiantes e"
    )

df_procesado=spark.sql(sql)
df_procesado=df_procesado.drop("ciudad")
df_procesado.printSchema()
# Out:
# root
#  |-- ciudad_union: integer (nullable = false)
#  |-- ciudad_tumaco: integer (nullable = false)
#  |-- ciudad_pasto: integer (nullable = false)
#  |-- ciudad_ipiales: integer (nullable = false)
#  |-- ciudad_samaniego: integer (nullable = false)
#  |-- cod_alumno: integer (nullable = false)
#  |-- sexo_f: integer (nullable = false)
#  |-- puntaje_ingreso: double (nullable = false)
#  |-- promedio_notas: double (nullable = false)
#  |-- total_creditos_logrados: double (nullable = false)
#  |-- biologia: double (nullable = false)
#  |-- matematicas: double (nullable = false)
#  |-- filosofia: double (nullable = false)
#  |-- fisica: double (nullable = false)
#  |-- historia: double (nullable = false)
#  |-- quimica: double (nullable = false)
#  |-- lenguaje: double (nullable = false)
#  |-- geografia: double (nullable = false)
#  |-- idiomas: double (nullable = false)
#  |-- sociales: double (nullable = false)
#  |-- lecturacritica: double (nullable = false)
#  |-- ciencias: double (nullable = false)
#  |-- razonamiento: double (nullable = false)
#  |-- competenciaciud: double (nullable = false)
#  |-- valor_matricula: double (nullable = false)
#  |-- valor_servicios: double (nullable = false)
#  |-- ingresos: double (nullable = false)
#  |-- vive_familia: integer (nullable = false)
#  |-- estrato: integer (nullable = false)
#  |-- estrato_vivira: integer (nullable = false)
#  |-- actualmente_trabaja: integer (nullable = false)
#  |-- valor_matric_colegio: integer (nullable = false)
#  |-- ano_pago_colegio: integer (nullable = false)
#  |-- ingresos_familiares: integer (nullable = false)
#  |-- ano_ingresos: double (nullable = false)
#  |-- numero_aportantes: double (nullable = false)
#  |-- numero_hermanos: double (nullable = false)
#  |-- numero_hermanos_est_superior: double (nullable = false)
#  |-- edad_inicio: double (nullable = false)
#  |-- edad_reporte: double (nullable = false)
#  |-- anio_reporte: double (nullable = false)
#  |-- clase: string (nullable = false)

# %% [markdown]
# # Aplicar Modelo Entrenado y Clasificar

# %% [markdown]
# Cargar modelo y variables

# %%
import joblib
from pyspark.ml.classification import DecisionTreeClassifier,DecisionTreeClassificationModel



modelo = DecisionTreeClassificationModel.load('D:\\CLASES\\ELECTIVA 3 BigData\\Taller_final\\modelo_99_arbol')
important_features=joblib.load('D:\\CLASES\\ELECTIVA 3 BigData\\Taller_final\\columnas_99.dat')

# %% [markdown]
# Filtrar variables

# %%
from pyspark.ml.feature import VectorAssembler

assembler_new = VectorAssembler(inputCols=important_features, outputCol='features')
evaluar = assembler_new.transform(df_procesado)


evaluar.select('features').take(1)
evaluar.select('features').show(5)
# Out:
# +--------------------+
# |            features|
# +--------------------+
# |[48.0,2.610869565...|
# |[33.0,2.588421052...|
# |[39.0,2.733663366...|
# |[36.0,2.941489361...|
# |[33.0,3.150000000...|
# +--------------------+
# only showing top 5 rows

# %% [markdown]
# Claficiar

# %%
df_pred = modelo.transform(evaluar)
df_pred.printSchema()
# Out:
# root
#  |-- ciudad_union: integer (nullable = false)
#  |-- ciudad_tumaco: integer (nullable = false)
#  |-- ciudad_pasto: integer (nullable = false)
#  |-- ciudad_ipiales: integer (nullable = false)
#  |-- ciudad_samaniego: integer (nullable = false)
#  |-- cod_alumno: integer (nullable = false)
#  |-- sexo_f: integer (nullable = false)
#  |-- puntaje_ingreso: double (nullable = false)
#  |-- promedio_notas: double (nullable = false)
#  |-- total_creditos_logrados: double (nullable = false)
#  |-- biologia: double (nullable = false)
#  |-- matematicas: double (nullable = false)
#  |-- filosofia: double (nullable = false)
#  |-- fisica: double (nullable = false)
#  |-- historia: double (nullable = false)
#  |-- quimica: double (nullable = false)
#  |-- lenguaje: double (nullable = false)
#  |-- geografia: double (nullable = false)
#  |-- idiomas: double (nullable = false)
#  |-- sociales: double (nullable = false)
#  |-- lecturacritica: double (nullable = false)
#  |-- ciencias: double (nullable = false)
#  |-- razonamiento: double (nullable = false)
#  |-- competenciaciud: double (nullable = false)
#  |-- valor_matricula: double (nullable = false)
#  |-- valor_servicios: double (nullable = false)
#  |-- ingresos: double (nullable = false)
#  |-- vive_familia: integer (nullable = false)
#  |-- estrato: integer (nullable = false)
#  |-- estrato_vivira: integer (nullable = false)
#  |-- actualmente_trabaja: integer (nullable = false)
#  |-- valor_matric_colegio: integer (nullable = false)
#  |-- ano_pago_colegio: integer (nullable = false)
#  |-- ingresos_familiares: integer (nullable = false)
#  |-- ano_ingresos: double (nullable = false)
#  |-- numero_aportantes: double (nullable = false)
#  |-- numero_hermanos: double (nullable = false)
#  |-- numero_hermanos_est_superior: double (nullable = false)
#  |-- edad_inicio: double (nullable = false)
#  |-- edad_reporte: double (nullable = false)
#  |-- anio_reporte: double (nullable = false)
#  |-- clase: string (nullable = false)
#  |-- features: vector (nullable = true)
#  |-- rawPrediction: vector (nullable = true)
#  |-- probability: vector (nullable = true)
#  |-- prediction: double (nullable = false)

# %%
df_pred=df_pred.withColumn("probabilidad",df_pred["probability"].cast("String"))

# %%
df_pred.createOrReplaceTempView('tabla_pred')
df_eval=spark.sql("SELECT cod_alumno,prediction,"+
          "cast(replace(split(probabilidad,',')[0],'[','')as double) as probabilidad_0,"+
          "cast(replace(split(probabilidad,',')[1],']','')as double) as probabilidad_1 FROM tabla_pred")
df_eval.show()
# Out:
# +----------+----------+-------------------+-------------------+
# |cod_alumno|prediction|     probabilidad_0|     probabilidad_1|
# +----------+----------+-------------------+-------------------+
# |      7644|       0.0| 0.9393939393939394|0.06060606060606061|
# |  22155233|       0.0|               0.75|               0.25|
# |  23033258|       1.0|0.03289473684210526| 0.9671052631578947|
# |  23038230|       0.0| 0.9166666666666666|0.08333333333333333|
# |  23038265|       0.0| 0.9117647058823529|0.08823529411764706|
# |  25033227|       1.0|0.03289473684210526| 0.9671052631578947|
# |  25033248|       0.0| 0.9024390243902439| 0.0975609756097561|
# |  25033264|       0.0| 0.9024390243902439| 0.0975609756097561|
# |  25155254|       1.0|0.03289473684210526| 0.9671052631578947|
# |  25155257|       1.0|0.03289473684210526| 0.9671052631578947|
# |  26033320|       1.0|0.03289473684210526| 0.9671052631578947|
# |  26160247|       1.0|0.08108108108108109|  0.918918918918919|
# |  27148234|       0.0|               0.75|               0.25|
# |  27149215|       1.0|0.42105263157894735| 0.5789473684210527|
# |  27166231|       1.0|0.03289473684210526| 0.9671052631578947|
# |  28033250|       0.0| 0.9024390243902439| 0.0975609756097561|
# |  28033257|       1.0|0.03289473684210526| 0.9671052631578947|
# |  28033279|       0.0| 0.9210526315789473|0.07894736842105263|
# |  28160218|       0.0| 0.9210526315789473|0.07894736842105263|
# |  29033229|       0.0| 0.9449838187702265|0.05501618122977346|
# +----------+----------+-------------------+-------------------+
# only showing top 20 rows

# %%
df_eval.printSchema()
# Out:
# root
#  |-- cod_alumno: integer (nullable = false)
#  |-- prediction: double (nullable = false)
#  |-- probabilidad_0: double (nullable = true)
#  |-- probabilidad_1: double (nullable = true)

# %%
df_eval.count()
# Out:
# 264

# %% [markdown]
# # Contar cantidad de registros por clase predicha

# %%
df_eval.groupby("prediction").count().show()
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |       0.0|  100|
# |       1.0|  164|
# +----------+-----+

# %%
df_eval.describe().show()
# Out:
# +-------+-------------------+------------------+--------------------+--------------------+
# |summary|         cod_alumno|        prediction|      probabilidad_0|      probabilidad_1|
# +-------+-------------------+------------------+--------------------+--------------------+
# |  count|                264|               264|                 264|                 264|
# |   mean|9.203732674545455E8|0.6212121212121212| 0.37631197375886194|   0.623688026241137|
# | stddev|9.448490349661958E8|0.4860065096859095| 0.43269583886000157|  0.4326958388600013|
# |    min|               7644|               0.0|0.003711952487008166|0.017699115044247787|
# |    max|         2141601270|               1.0|  0.9823008849557522|  0.9962880475129918|
# +-------+-------------------+------------------+--------------------+--------------------+

# %%
df_eval.write.csv('D:\\CLASES\\ELECTIVA 3 BigData\\Taller_final\\entrega_guerrero.csv',sep='|',header="true")
